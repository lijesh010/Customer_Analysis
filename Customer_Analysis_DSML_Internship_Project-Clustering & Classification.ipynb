# %% [markdown]
# # <p style="font-family:newtimeroman;color:#182F2F;font-size:200%;text-align:center;border-radius:10px 10px;">Customer Analysis- Clustering</p>

# %% [markdown]
# ![im8hlbo8.png](attachment:im8hlbo8.png)

# %% [markdown]
# # <p style="font-family:newtimeroman;color:#182F2F;font-size:100%;text-align:left;border-radius:10px 10px;">PROBLEM STATEMENT:</p>
# A well known company with numerous products needs to analyze their customer behavior and
# classify them whether they will accept the campaigns held by the company. Also, cluster the
# customers into different segments.

# %% [markdown]
# # <p style="font-family:newtimeroman;color:#182F2F;font-size:100%;text-align:left;border-radius:10px 10px;">GOALS:
# The objective of this project is to build a model, using historical data Focus on all steps of data
# science (EDA, data processing, model, evaluation, charts)
# 1. Highlight any trend in data, deep insight, novel steps that you take
# 2. Highlight next steps and improvements.
# 3. Apply classification and clustering machine learning algorithms and evaluate it using Test dataset.

# %% [markdown]
# # <p style="font-family:newtimeroman;color:#182F2F;font-size:100%;text-align:left;border-radius:10px 10px;">ABOUT THE DATASET:
# **PEOPLE**
#
# 1. ID: Customer's unique identifier
# 2. Year_Birth: Customer's birth year
# 3. Education: Customer's education level
# 4. Marital_Status: Customer's marital status
# 5. Income: Customer's yearly household income
# 6. Kidhome: Number of children in customer's household
# 7. Teenhome: Number of teenagers in customer's household
# 8. Dt_Customer: Date of customer's enrollment with the company
# 9. Recency: Number of days since customer's last purchase
# 10. Complain: 1 if the customer complained in the last 2 years, 0 otherwise
#
# **PRODUCTS**
#
# 1. MntWines: Amount spent on wine in last 2 years
# 2. MntFruits: Amount spent on fruits in last 2 years
# 3. MntMeatProducts: Amount spent on meat in last 2 years
# 4. MntFishProducts: Amount spent on fish in last 2 years
# 5. MntSweetProducts: Amount spent on sweets in last 2 years
# 6. MntGoldProds: Amount spent on gold in last 2 years
#
# **PROMOTION**
#
# 1. NumDealsPurchases: Number of purchases made with a discount
# 2. AcceptedCmp1: 1 if customer accepted the offer in the 1st campaign, 0 otherwise
# 3. AcceptedCmp2: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
# 4. AcceptedCmp3: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
# 5. AcceptedCmp4: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
# 6. AcceptedCmp5: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
# 7. Response: 1 if customer accepted the offer in the last campaign, 0 otherwise
#
# **PLACE**
#
# 1. NumWebPurchases: Number of purchases made through the company’s website
# 2. NumCatalogPurchases: Number of purchases made using a catalogue
# 3. NumStorePurchases: Number of purchases made directly in stores
# 4. NumWebVisitsMonth: Number of visits to company’s website in the last month

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">TABLE OF CONTENTS</p>

# %% [markdown]
# **1. IMPORT LIBRARIES**
#
# **2. LOAD DATASET**
#
# **3. DATA EXPLORATION**
#
#     3.1 SUMMARIZE DATASET
#     3.2 FEATURE ENGINEERING
#
# **4. EXPLORATORY DATA ANALYSIS (EDA)**
#
#     4.1 UNIVARIATE ANALYSIS
#     4.2 BIVARIATE ANALYSIS
#     4.3 MULTIIVARIATE ANALYSIS
#
# **5. DATA PREPROCESSING**
#
#     5.1 ENCODING
#     5.2 SCALING
#
#
# **6. CLUSTERING**
#
#     7.1 AGGLOMERATIVE CLUSTERING
#     7.2 KMEANS CLUSTERING
#
#
# **7. CLUSTER ANALYSIS**
#
# **8. PROFILING**
#
# **9. CLASSIFICATION ALGORITHM**
#
#     9.1 RANDOM FOREST CLASSIFIER ALGORITHM
#
# **10. CONCLUSION**
#
# **11. END**

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">IMPORT LIBRARIES</p>

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns",None)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">LOAD DATASET</p>

# %%
#load dataset(training and testing datasets separately)
df_training=pd.read_csv('market_train.csv')
df_testing=pd.read_csv('market_test.csv')

# %%
df_training
# Out:
#       Unnamed: 0.1  Unnamed: 0    ID  Year_Birth Education Marital_Status  \
# 0                0           0  5524        1957        S1         Lajang
# 1                1           1  2174        1954        S1         Lajang
# 2                2           2  4141        1965        S1    Bertunangan
# 3                3           3  6182        1984        S1    Bertunangan
# 4                4           4  5324        1981        S3        Menikah
# ...            ...         ...   ...         ...       ...            ...
# 1675          1675        1675  4712        1991        D3    Bertunangan
# 1676          1676        1676  1170        1975        S1        Menikah
# 1677          1677        1677  6347        1979       SMA         Lajang
# 1678          1678        1678  4065        1976        S3        Menikah
# 1679          1679        1679  8230        1980        S1        Menikah
#
#           Income  Kidhome  Teenhome Dt_Customer  Recency  MntCoke  MntFruits  \
# 0     58138000.0        0         0  04-09-2012       58   635000      88000
# 1     46344000.0        1         1  08-03-2014       38    11000       1000
# 2     71613000.0        0         0  21-08-2013       26   426000      49000
# 3     26646000.0        1         0  10-02-2014       26    11000       4000
# 4     58293000.0        1         0  19-01-2014       94   173000      43000
# ...          ...      ...       ...         ...      ...      ...        ...
# 1675  20193000.0        0         0  28-11-2012       18     8000       8000
# 1676  27573000.0        1         0  25-03-2013       45    50000      15000
# 1677  15862000.0        1         0  27-06-2013       26     1000       1000
# 1678  49544000.0        1         0  12-02-2013        0   308000          0
# 1679  33228000.0        1         0  23-01-2014       28    22000       2000
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0              546000           172000             88000         88000
# 1                6000             2000              1000          6000
# 2              127000           111000             21000         42000
# 3               20000            10000              3000          5000
# 4              118000            46000             27000         15000
# ...               ...              ...               ...           ...
# 1675            22000            24000             11000          9000
# 1676           110000            39000             15000         15000
# 1677             4000            11000              9000         10000
# 1678            73000                0                 0         23000
# 1679            31000             7000              4000          5000
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0                     3                8                   10
# 1                     2                1                    1
# 2                     1                8                    2
# 3                     2                2                    0
# 4                     5                5                    3
# ...                 ...              ...                  ...
# 1675                  1                1                    1
# 1676                  4                5                    1
# 1677                  1                1                    0
# 1678                  2                5                    1
# 1679                  1                2                    0
#
#       NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 0                     4                  7             0             0
# 1                     2                  5             0             0
# 2                    10                  4             0             0
# 3                     4                  6             0             0
# 4                     6                  5             0             0
# ...                 ...                ...           ...           ...
# 1675                  4                  4             0             0
# 1676                  4                  8             0             0
# 1677                  3                  8             0             0
# 1678                  8                  7             0             0
# 1679                  3                  7             0             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  \
# 0                0             0             0         0              3
# 1                0             0             0         0              3
# 2                0             0             0         0              3
# 3                0             0             0         0              3
# 4                0             0             0         0              3
# ...            ...           ...           ...       ...            ...
# 1675             0             0             0         0              3
# 1676             0             0             0         0              3
# 1677             0             0             0         0              3
# 1678             0             0             0         0              3
# 1679             0             0             0         0              3
#
#       Z_Revenue  Response
# 0            11         1
# 1            11         0
# 2            11         0
# 3            11         0
# 4            11         0
# ...         ...       ...
# 1675         11         0
# 1676         11         0
# 1677         11         0
# 1678         11         0
# 1679         11         0
#
# [1680 rows x 31 columns]

# %%
df_testing
# Out:
#      Unnamed: 0.1  Unnamed: 0     ID  Year_Birth Education Marital_Status  \
# 0            1681        1681   5939        1971        S1    Bertunangan
# 1            1682        1682   2156        1955        S3        Menikah
# 2            1683        1683   7788        1983        S3        Menikah
# 3            1684        1684  10323        1952        S1        Menikah
# 4            1685        1685   7947        1969        S1        Menikah
# ..            ...         ...    ...         ...       ...            ...
# 554          2235        2235  10870        1967        S1        Menikah
# 555          2236        2236   4001        1946        S3    Bertunangan
# 556          2237        2237   7270        1981        S1          Cerai
# 557          2238        2238   8235        1956        S2    Bertunangan
# 558          2239        2239   9405        1954        S3        Menikah
#
#          Income  Kidhome  Teenhome Dt_Customer  Recency  MntCoke  MntFruits  \
# 0    38232000.0        1         1  17-01-2014       84    43000       5000
# 1    22554000.0        1         1  03-11-2012       38    27000          0
# 2    23536000.0        1         0  04-06-2014       53     6000          0
# 3    49413000.0        0         1  25-10-2013       88   205000       7000
# 4    42231000.0        1         1  25-03-2014       99    24000          0
# ..          ...      ...       ...         ...      ...      ...        ...
# 554  61223000.0        0         1  13-06-2013       46   709000      43000
# 555  64014000.0        2         1  10-06-2014       56   406000          0
# 556  56981000.0        0         0  25-01-2014       91   908000      48000
# 557  69245000.0        0         1  24-01-2014        8   428000      30000
# 558  52869000.0        1         1  15-10-2012       40    84000       3000
#
#      MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0              28000             7000              6000         33000
# 1              10000                0                 0          4000
# 2               3000                0                 0          1000
# 3              41000             3000              2000         46000
# 4               8000                0              1000          4000
# ..               ...              ...               ...           ...
# 554           182000            42000            118000        247000
# 555            30000                0                 0          8000
# 556           217000            32000             12000         24000
# 557           214000            80000             30000         61000
# 558            61000             2000              1000         21000
#
#      NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0                    4                3                    1
# 1                    4                2                    0
# 2                    1                0                    0
# 3                    2                4                    2
# 4                    1                1                    0
# ..                 ...              ...                  ...
# 554                  2                9                    3
# 555                  7                8                    2
# 556                  1                2                    3
# 557                  2                6                    5
# 558                  3                3                    1
#
#      NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 0                    3                  5             0             0
# 1                    4                  5             0             0
# 2                    3                  3             0             0
# 3                    5                  5             0             0
# 4                    3                  5             0             0
# ..                 ...                ...           ...           ...
# 554                  4                  5             0             0
# 555                  5                  7             0             0
# 556                 13                  6             0             1
# 557                 10                  3             0             0
# 558                  4                  7             0             0
#
#      AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  \
# 0               0             0             0         0              3
# 1               0             0             0         0              3
# 2               0             0             0         0              3
# 3               0             0             0         0              3
# 4               0             0             0         0              3
# ..            ...           ...           ...       ...            ...
# 554             0             0             0         0              3
# 555             0             1             0         0              3
# 556             0             0             0         0              3
# 557             0             0             0         0              3
# 558             0             0             0         0              3
#
#      Z_Revenue  Response
# 0           11         0
# 1           11         0
# 2           11         0
# 3           11         0
# 4           11         0
# ..         ...       ...
# 554         11         0
# 555         11         0
# 556         11         0
# 557         11         0
# 558         11         1
#
# [559 rows x 31 columns]

# %% [markdown]
# The first two columns are junk, so they should be removed from both training and testing dataset before starting the analysis

# %%
#remove the unwanted columns

df_train=df_training.iloc[:,2:]
df_train
# Out:
#         ID  Year_Birth Education Marital_Status      Income  Kidhome  \
# 0     5524        1957        S1         Lajang  58138000.0        0
# 1     2174        1954        S1         Lajang  46344000.0        1
# 2     4141        1965        S1    Bertunangan  71613000.0        0
# 3     6182        1984        S1    Bertunangan  26646000.0        1
# 4     5324        1981        S3        Menikah  58293000.0        1
# ...    ...         ...       ...            ...         ...      ...
# 1675  4712        1991        D3    Bertunangan  20193000.0        0
# 1676  1170        1975        S1        Menikah  27573000.0        1
# 1677  6347        1979       SMA         Lajang  15862000.0        1
# 1678  4065        1976        S3        Menikah  49544000.0        1
# 1679  8230        1980        S1        Menikah  33228000.0        1
#
#       Teenhome Dt_Customer  Recency  MntCoke  MntFruits  MntMeatProducts  \
# 0            0  04-09-2012       58   635000      88000           546000
# 1            1  08-03-2014       38    11000       1000             6000
# 2            0  21-08-2013       26   426000      49000           127000
# 3            0  10-02-2014       26    11000       4000            20000
# 4            0  19-01-2014       94   173000      43000           118000
# ...        ...         ...      ...      ...        ...              ...
# 1675         0  28-11-2012       18     8000       8000            22000
# 1676         0  25-03-2013       45    50000      15000           110000
# 1677         0  27-06-2013       26     1000       1000             4000
# 1678         0  12-02-2013        0   308000          0            73000
# 1679         0  23-01-2014       28    22000       2000            31000
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0              172000             88000         88000                  3
# 1                2000              1000          6000                  2
# 2              111000             21000         42000                  1
# 3               10000              3000          5000                  2
# 4               46000             27000         15000                  5
# ...               ...               ...           ...                ...
# 1675            24000             11000          9000                  1
# 1676            39000             15000         15000                  4
# 1677            11000              9000         10000                  1
# 1678                0                 0         23000                  2
# 1679             7000              4000          5000                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   8                   10                  4
# 1                   1                    1                  2
# 2                   8                    2                 10
# 3                   2                    0                  4
# 4                   5                    3                  6
# ...               ...                  ...                ...
# 1675                1                    1                  4
# 1676                5                    1                  4
# 1677                1                    0                  3
# 1678                5                    1                  8
# 1679                2                    0                  3
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                     7             0             0             0
# 1                     5             0             0             0
# 2                     4             0             0             0
# 3                     6             0             0             0
# 4                     5             0             0             0
# ...                 ...           ...           ...           ...
# 1675                  4             0             0             0
# 1676                  8             0             0             0
# 1677                  8             0             0             0
# 1678                  7             0             0             0
# 1679                  7             0             0             0
#
#       AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response
# 0                0             0         0              3         11         1
# 1                0             0         0              3         11         0
# 2                0             0         0              3         11         0
# 3                0             0         0              3         11         0
# 4                0             0         0              3         11         0
# ...            ...           ...       ...            ...        ...       ...
# 1675             0             0         0              3         11         0
# 1676             0             0         0              3         11         0
# 1677             0             0         0              3         11         0
# 1678             0             0         0              3         11         0
# 1679             0             0         0              3         11         0
#
# [1680 rows x 29 columns]

# %%
#remove the unanted columns

df_test=df_testing.iloc[:,2:]
df_test
# Out:
#         ID  Year_Birth Education Marital_Status      Income  Kidhome  \
# 0     5939        1971        S1    Bertunangan  38232000.0        1
# 1     2156        1955        S3        Menikah  22554000.0        1
# 2     7788        1983        S3        Menikah  23536000.0        1
# 3    10323        1952        S1        Menikah  49413000.0        0
# 4     7947        1969        S1        Menikah  42231000.0        1
# ..     ...         ...       ...            ...         ...      ...
# 554  10870        1967        S1        Menikah  61223000.0        0
# 555   4001        1946        S3    Bertunangan  64014000.0        2
# 556   7270        1981        S1          Cerai  56981000.0        0
# 557   8235        1956        S2    Bertunangan  69245000.0        0
# 558   9405        1954        S3        Menikah  52869000.0        1
#
#      Teenhome Dt_Customer  Recency  MntCoke  MntFruits  MntMeatProducts  \
# 0           1  17-01-2014       84    43000       5000            28000
# 1           1  03-11-2012       38    27000          0            10000
# 2           0  04-06-2014       53     6000          0             3000
# 3           1  25-10-2013       88   205000       7000            41000
# 4           1  25-03-2014       99    24000          0             8000
# ..        ...         ...      ...      ...        ...              ...
# 554         1  13-06-2013       46   709000      43000           182000
# 555         1  10-06-2014       56   406000          0            30000
# 556         0  25-01-2014       91   908000      48000           217000
# 557         1  24-01-2014        8   428000      30000           214000
# 558         1  15-10-2012       40    84000       3000            61000
#
#      MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 0               7000              6000         33000                  4
# 1                  0                 0          4000                  4
# 2                  0                 0          1000                  1
# 3               3000              2000         46000                  2
# 4                  0              1000          4000                  1
# ..               ...               ...           ...                ...
# 554            42000            118000        247000                  2
# 555                0                 0          8000                  7
# 556            32000             12000         24000                  1
# 557            80000             30000         61000                  2
# 558             2000              1000         21000                  3
#
#      NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  3                    1                  3
# 1                  2                    0                  4
# 2                  0                    0                  3
# 3                  4                    2                  5
# 4                  1                    0                  3
# ..               ...                  ...                ...
# 554                9                    3                  4
# 555                8                    2                  5
# 556                2                    3                 13
# 557                6                    5                 10
# 558                3                    1                  4
#
#      NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                    5             0             0             0
# 1                    5             0             0             0
# 2                    3             0             0             0
# 3                    5             0             0             0
# 4                    5             0             0             0
# ..                 ...           ...           ...           ...
# 554                  5             0             0             0
# 555                  7             0             0             0
# 556                  6             0             1             0
# 557                  3             0             0             0
# 558                  7             0             0             0
#
#      AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response
# 0               0             0         0              3         11         0
# 1               0             0         0              3         11         0
# 2               0             0         0              3         11         0
# 3               0             0         0              3         11         0
# 4               0             0         0              3         11         0
# ..            ...           ...       ...            ...        ...       ...
# 554             0             0         0              3         11         0
# 555             1             0         0              3         11         0
# 556             0             0         0              3         11         0
# 557             0             0         0              3         11         0
# 558             0             0         0              3         11         1
#
# [559 rows x 29 columns]

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">DATA EXPLORATION</p>

# %%
#summarize datasets

df_train.shape
# Out:
# (1680, 29)

# %%
df_test.shape
# Out:
# (559, 29)

# %% [markdown]
# The training dataset contains 1680 rows and 29 columns.
#
# The testing dataset contains 559 rows and 29 columns.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680 entries, 0 to 1679
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   1680 non-null   int64
#  1   Year_Birth           1680 non-null   int64
#  2   Education            1680 non-null   object
#  3   Marital_Status       1680 non-null   object
#  4   Income               1663 non-null   float64
#  5   Kidhome              1680 non-null   int64
#  6   Teenhome             1680 non-null   int64
#  7   Dt_Customer          1680 non-null   object
#  8   Recency              1680 non-null   int64
#  9   MntCoke              1680 non-null   int64
#  10  MntFruits            1680 non-null   int64
#  11  MntMeatProducts      1680 non-null   int64
#  12  MntFishProducts      1680 non-null   int64
#  13  MntSweetProducts     1680 non-null   int64
#  14  MntGoldProds         1680 non-null   int64
#  15  NumDealsPurchases    1680 non-null   int64
#  16  NumWebPurchases      1680 non-null   int64
#  17  NumCatalogPurchases  1680 non-null   int64
#  18  NumStorePurchases    1680 non-null   int64
#  19  NumWebVisitsMonth    1680 non-null   int64
#  20  AcceptedCmp3         1680 non-null   int64
#  21  AcceptedCmp4         1680 non-null   int64
#  22  AcceptedCmp5         1680 non-null   int64
#  23  AcceptedCmp1         1680 non-null   int64
#  24  AcceptedCmp2         1680 non-null   int64
#  25  Complain             1680 non-null   int64
#  26  Z_CostContact        1680 non-null   int64
#  27  Z_Revenue            1680 non-null   int64
#  28  Response             1680 non-null   int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 380.8+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   559 non-null    int64
#  1   Year_Birth           559 non-null    int64
#  2   Education            559 non-null    object
#  3   Marital_Status       559 non-null    object
#  4   Income               552 non-null    float64
#  5   Kidhome              559 non-null    int64
#  6   Teenhome             559 non-null    int64
#  7   Dt_Customer          559 non-null    object
#  8   Recency              559 non-null    int64
#  9   MntCoke              559 non-null    int64
#  10  MntFruits            559 non-null    int64
#  11  MntMeatProducts      559 non-null    int64
#  12  MntFishProducts      559 non-null    int64
#  13  MntSweetProducts     559 non-null    int64
#  14  MntGoldProds         559 non-null    int64
#  15  NumDealsPurchases    559 non-null    int64
#  16  NumWebPurchases      559 non-null    int64
#  17  NumCatalogPurchases  559 non-null    int64
#  18  NumStorePurchases    559 non-null    int64
#  19  NumWebVisitsMonth    559 non-null    int64
#  20  AcceptedCmp3         559 non-null    int64
#  21  AcceptedCmp4         559 non-null    int64
#  22  AcceptedCmp5         559 non-null    int64
#  23  AcceptedCmp1         559 non-null    int64
#  24  AcceptedCmp2         559 non-null    int64
#  25  Complain             559 non-null    int64
#  26  Z_CostContact        559 non-null    int64
#  27  Z_Revenue            559 non-null    int64
#  28  Response             559 non-null    int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 126.8+ KB

# %%
# check for duplicated rows

df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Both the datasets contains no duplicated rows.

# %%
# check for null/missing values

df_train.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 17
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntCoke                 0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 7
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntCoke                0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %% [markdown]
# ### Observations:
# 1. As compared to the total count of rows, the rows with null values are less so better to drop it.
# 2. Remove the rows that having null values using 'dropna' method

# %%
df_train.dropna(inplace=True)
df_test.dropna(inplace=True)

# %%
df_train.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntCoke                0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntCoke                0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %% [markdown]
# The following table indicates the statistical analysis of the training dataset.From whuch we can identify the count of rows,mean,standard deviation, minimum value, 25 percentile, 50 percentile, 75 percentile and maximum values in each features.
# for a normally distributed dataset, the meanand 50 percentile values are closer, variations from each indiactes the presence of outliers in the corresponding features.

# %%
# statistical analysis

df_train.describe()
# Out:
#                  ID   Year_Birth        Income      Kidhome     Teenhome  \
# count   1663.000000  1663.000000  1.663000e+03  1663.000000  1663.000000
# mean    5547.541191  1968.849068  5.201434e+07     0.449188     0.499098
# std     3240.106517    12.037325  2.148248e+07     0.544890     0.549449
# min        0.000000  1893.000000  1.730000e+06     0.000000     0.000000
# 25%     2814.500000  1960.000000  3.568800e+07     0.000000     0.000000
# 50%     5376.000000  1970.000000  5.125000e+07     0.000000     0.000000
# 75%     8369.500000  1977.000000  6.812200e+07     1.000000     1.000000
# max    11191.000000  1996.000000  1.623970e+08     2.000000     2.000000
#
#            Recency       MntCoke      MntFruits  MntMeatProducts  \
# count  1663.000000  1.663000e+03    1663.000000     1.663000e+03
# mean     49.061335  3.060469e+05   25978.352375     1.664546e+05
# std      28.914182  3.392420e+05   39576.041604     2.248949e+05
# min       0.000000  0.000000e+00       0.000000     1.000000e+03
# 25%      24.000000  2.400000e+04    1000.000000     1.600000e+04
# 50%      50.000000  1.730000e+05    8000.000000     6.800000e+04
# 75%      74.000000  4.990000e+05   32000.000000     2.345000e+05
# max      99.000000  1.492000e+06  199000.000000     1.725000e+06
#
#        MntFishProducts  MntSweetProducts   MntGoldProds  NumDealsPurchases  \
# count      1663.000000       1663.000000    1663.000000        1663.000000
# mean      37110.042093      26979.555021   43331.328924           2.338545
# std       54348.868950      41273.567857   50904.197540           1.956260
# min           0.000000          0.000000       0.000000           0.000000
# 25%        3000.000000       1000.000000    9000.000000           1.000000
# 50%       12000.000000       8000.000000   24000.000000           2.000000
# 75%       48000.000000      32000.000000   55000.000000           3.000000
# max      259000.000000     198000.000000  262000.000000          15.000000
#
#        NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# count      1663.000000          1663.000000        1663.000000
# mean          4.038485             2.682502           5.797956
# std           2.616657             2.980317           3.245112
# min           0.000000             0.000000           0.000000
# 25%           2.000000             0.000000           3.000000
# 50%           4.000000             2.000000           5.000000
# 75%           6.000000             4.000000           8.000000
# max          11.000000            28.000000          13.000000
#
#        NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# count        1663.000000   1663.000000   1663.000000   1663.000000
# mean            5.331930      0.072159      0.073963      0.069753
# std             2.451058      0.258828      0.261789      0.254808
# min             0.000000      0.000000      0.000000      0.000000
# 25%             3.000000      0.000000      0.000000      0.000000
# 50%             6.000000      0.000000      0.000000      0.000000
# 75%             7.000000      0.000000      0.000000      0.000000
# max            20.000000      1.000000      1.000000      1.000000
#
#        AcceptedCmp1  AcceptedCmp2     Complain  Z_CostContact  Z_Revenue  \
# count   1663.000000   1663.000000  1663.000000         1663.0     1663.0
# mean       0.061936      0.012026     0.010222            3.0       11.0
# std        0.241112      0.109037     0.100618            0.0        0.0
# min        0.000000      0.000000     0.000000            3.0       11.0
# 25%        0.000000      0.000000     0.000000            3.0       11.0
# 50%        0.000000      0.000000     0.000000            3.0       11.0
# 75%        0.000000      0.000000     0.000000            3.0       11.0
# max        1.000000      1.000000     1.000000            3.0       11.0
#
#           Response
# count  1663.000000
# mean      0.145520
# std       0.352731
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# The following information provides the count of unique values for each feature. The columns 'Z_CostContact' and 'Z_Revenue' indicate that there is only one type of element in these features. Therefore, they will not contribute to the upcoming analytical parts, so better to drop these features.

# %%
# unique values in each columns

df_train.nunique()
# Out:
# ID                     1663
# Year_Birth               58
# Education                 5
# Marital_Status            6
# Income                 1512
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             619
# Recency                 100
# MntCoke                 679
# MntFruits               151
# MntMeatProducts         482
# MntFishProducts         171
# MntSweetProducts        166
# MntGoldProds            194
# NumDealsPurchases        15
# NumWebPurchases          12
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        15
# AcceptedCmp3              2
# AcceptedCmp4              2
# AcceptedCmp5              2
# AcceptedCmp1              2
# AcceptedCmp2              2
# Complain                  2
# Z_CostContact             1
# Z_Revenue                 1
# Response                  2
# dtype: int64

# %% [markdown]
# ### Observation:
# 1. The 'Z_CostContact' and 'Z_Revenue' columns contains only 1 item and they are not going to contribute anything in the model building. So we can drop them.

# %%
# drop the unwanted columns

df_train.drop(['Z_CostContact','Z_Revenue'], axis=1, inplace=True)
df_test.drop(['Z_CostContact','Z_Revenue'], axis=1, inplace=True)

# %%
print('df_train size: ',df_train.shape)
print('df_test size: ',df_test.shape)
# Out:
# df_train size:  (1663, 27)
# df_test size:  (552, 27)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1663 entries, 0 to 1679
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   1663 non-null   int64
#  1   Year_Birth           1663 non-null   int64
#  2   Education            1663 non-null   object
#  3   Marital_Status       1663 non-null   object
#  4   Income               1663 non-null   float64
#  5   Kidhome              1663 non-null   int64
#  6   Teenhome             1663 non-null   int64
#  7   Dt_Customer          1663 non-null   object
#  8   Recency              1663 non-null   int64
#  9   MntCoke              1663 non-null   int64
#  10  MntFruits            1663 non-null   int64
#  11  MntMeatProducts      1663 non-null   int64
#  12  MntFishProducts      1663 non-null   int64
#  13  MntSweetProducts     1663 non-null   int64
#  14  MntGoldProds         1663 non-null   int64
#  15  NumDealsPurchases    1663 non-null   int64
#  16  NumWebPurchases      1663 non-null   int64
#  17  NumCatalogPurchases  1663 non-null   int64
#  18  NumStorePurchases    1663 non-null   int64
#  19  NumWebVisitsMonth    1663 non-null   int64
#  20  AcceptedCmp3         1663 non-null   int64
#  21  AcceptedCmp4         1663 non-null   int64
#  22  AcceptedCmp5         1663 non-null   int64
#  23  AcceptedCmp1         1663 non-null   int64
#  24  AcceptedCmp2         1663 non-null   int64
#  25  Complain             1663 non-null   int64
#  26  Response             1663 non-null   int64
# dtypes: float64(1), int64(23), object(3)
# memory usage: 363.8+ KB

# %% [markdown]
# The following categorical columns contains data related to the country Indonesia.For better understanding convert theese datas to generalised form.
#
# So convert the datas in Indonesian language to english.

# %%
# Unique values in categorical features

df_train['Education'].value_counts()
# Out:
# S1     825
# S3     369
# S2     277
# D3     157
# SMA     35
# Name: Education, dtype: int64

# %%
df_train['Marital_Status'].value_counts()
# Out:
# Menikah        644
# Bertunangan    434
# Lajang         353
# Cerai          177
# Janda           52
# Duda             3
# Name: Marital_Status, dtype: int64

# %%
# to get more understanding translate this indonesian words to english

df_train["Marital_Status"]=df_train["Marital_Status"].replace({"Menikah":"Married", "Bertunangan":"Engaged", "Lajang":"Single", "Cerai":"Divorced", "Janda":"Widow", "Duda":"Widow"})
df_train["Education"]=df_train["Education"].replace({"S1":"BSc", "S2":"MSc", "S3":"PhD", "D3":"Diploma", "SMA":"Diploma"})

df_test["Marital_Status"]=df_test["Marital_Status"].replace({"Menikah":"Married", "Bertunangan":"Engaged", "Lajang":"Single", "Cerai":"Divorced", "Janda":"Widow", "Duda":"Widow"})
df_test["Education"]=df_test["Education"].replace({"S1":"BSc", "S2":"MSc", "S3":"PhD", "D3":"Diploma", "SMA":"Diploma"})

# %%
df_train['Education'].value_counts()
# Out:
# BSc        825
# PhD        369
# MSc        277
# Diploma    192
# Name: Education, dtype: int64

# %%
df_train['Marital_Status'].value_counts()
# Out:
# Married     644
# Engaged     434
# Single      353
# Divorced    177
# Widow        55
# Name: Marital_Status, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
df_train.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntCoke', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Response'],
#       dtype='object')

# %% [markdown]
# ### performing the following steps to engineer some new features:
#
# 1. Extract the **"Age"** of a customer by the **"Year_Birth"** indicating the birth year of the respective person.
# 2. Create another feature **"Spent"** indicating the total amount spent by the customer in various categories over the span of purchasing.
# 3. Create another feature **"Living_With"** out of **"Marital_Status"** to extract the living situation of couples.
# 4. Create a feature **"Children"** to indicate total children in a household that is, kids and teenagers.
# 5. To get further clarity of household, Creating feature indicating **"Family_Size"**
# 6. Create a feature **"Is_Parent"** to indicate parenthood status
# 7. Create three categories in the **"Education"** by simplifying its value counts.
# 8. Dropping some of the redundant features

# %%
import datetime
#Age of customer today 
df_train["Age"] = 2023-df_train["Year_Birth"]

#Total spendings on various items
df_train["Spent"] = df_train["MntCoke"]+ df_train["MntFruits"]+ df_train["MntMeatProducts"]+ df_train["MntFishProducts"]+ df_train["MntSweetProducts"]+ df_train["MntGoldProds"]

#Deriving living situation by marital status"Alone"
df_train["Living_With"]=df_train["Marital_Status"].replace({"Married":"Partner", "Engaged":"Alone", "Single":"Alone", "Widow":"Alone", "Divorced":"Alone"})

#Feature indicating total children living in the household
df_train["Children"]=df_train["Kidhome"]+df_train["Teenhome"]

#Feature for total members in the householde
df_train["Family_Size"] = df_train["Living_With"].replace({"Alone": 1, "Partner":2})+ df_train["Children"]

#Feature parenthood
df_train["Is_Parent"] = np.where(df_train.Children> 0, 1, 0)

#Segmenting education levels in three groups
df_train["Education"]=df_train["Education"].replace({"Diploma":"Undergraduate", "BSc":"Graduate", "MSc":"Postgraduate", "PhD":"Postgraduate"})

#Dropping some of the redundant features
to_drop = ["Marital_Status", "Dt_Customer", "Year_Birth", "ID"]
df_train = df_train.drop(to_drop, axis=1)

# %%
# same in testing dataset

#Age of customer today 
df_test["Age"] = 2023-df_test["Year_Birth"]

#Total spendings on various items
df_test["Spent"] = df_test["MntCoke"]+ df_test["MntFruits"]+ df_test["MntMeatProducts"]+ df_test["MntFishProducts"]+ df_test["MntSweetProducts"]+ df_test["MntGoldProds"]

#Deriving living situation by marital status"Alone"
df_test["Living_With"]=df_test["Marital_Status"].replace({"Married":"Partner", "Engaged":"Alone", "Single":"Alone", "Widow":"Alone", "Divorced":"Alone"})

#Feature indicating total children living in the household
df_test["Children"]=df_test["Kidhome"]+df_train["Teenhome"]

#Feature for total members in the householde
df_test["Family_Size"] = df_test["Living_With"].replace({"Alone": 1, "Partner":2})+ df_test["Children"]

#Feature parenthood
df_test["Is_Parent"] = np.where(df_test.Children> 0, 1, 0)

#Segmenting education levels in three groups
df_test["Education"]=df_test["Education"].replace({"Diploma":"Undergraduate", "BSc":"Graduate", "MSc":"Postgraduate", "PhD":"Postgraduate"})

#Dropping some of the redundant features
to_drop = ["Marital_Status", "Dt_Customer", "Year_Birth", "ID"]
df_test = df_test.drop(to_drop, axis=1)
df_test.dropna(inplace=True)

# %%
df_train.head()
# Out:
#       Education      Income  Kidhome  Teenhome  Recency  MntCoke  MntFruits  \
# 0      Graduate  58138000.0        0         0       58   635000      88000
# 1      Graduate  46344000.0        1         1       38    11000       1000
# 2      Graduate  71613000.0        0         0       26   426000      49000
# 3      Graduate  26646000.0        1         0       26    11000       4000
# 4  Postgraduate  58293000.0        1         0       94   173000      43000
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0           546000           172000             88000         88000
# 1             6000             2000              1000          6000
# 2           127000           111000             21000         42000
# 3            20000            10000              3000          5000
# 4           118000            46000             27000         15000
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  3                8                   10                  4
# 1                  2                1                    1                  2
# 2                  1                8                    2                 10
# 3                  2                2                    0                  4
# 4                  5                5                    3                  6
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  7             0             0             0             0
# 1                  5             0             0             0             0
# 2                  4             0             0             0             0
# 3                  6             0             0             0             0
# 4                  5             0             0             0             0
#
#    AcceptedCmp2  Complain  Response  Age    Spent Living_With  Children  \
# 0             0         0         1   66  1617000       Alone         0
# 1             0         0         0   69    27000       Alone         2
# 2             0         0         0   58   776000       Alone         0
# 3             0         0         0   39    53000       Alone         1
# 4             0         0         0   42   422000     Partner         1
#
#    Family_Size  Is_Parent
# 0            1          0
# 1            3          1
# 2            1          0
# 3            2          1
# 4            3          1

# %%
df_test.head()
# Out:
#       Education      Income  Kidhome  Teenhome  Recency  MntCoke  MntFruits  \
# 0      Graduate  38232000.0        1         1       84    43000       5000
# 1  Postgraduate  22554000.0        1         1       38    27000          0
# 2  Postgraduate  23536000.0        1         0       53     6000          0
# 3      Graduate  49413000.0        0         1       88   205000       7000
# 4      Graduate  42231000.0        1         1       99    24000          0
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0            28000             7000              6000         33000
# 1            10000                0                 0          4000
# 2             3000                0                 0          1000
# 3            41000             3000              2000         46000
# 4             8000                0              1000          4000
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  4                3                    1                  3
# 1                  4                2                    0                  4
# 2                  1                0                    0                  3
# 3                  2                4                    2                  5
# 4                  1                1                    0                  3
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  5             0             0             0             0
# 1                  5             0             0             0             0
# 2                  3             0             0             0             0
# 3                  5             0             0             0             0
# 4                  5             0             0             0             0
#
#    AcceptedCmp2  Complain  Response  Age   Spent Living_With  Children  \
# 0             0         0         0   52  122000       Alone       1.0
# 1             0         0         0   68   41000     Partner       2.0
# 2             0         0         0   40   10000     Partner       1.0
# 3             0         0         0   71  304000     Partner       0.0
# 4             0         0         0   54   37000     Partner       1.0
#
#    Family_Size  Is_Parent
# 0          2.0          1
# 1          4.0          1
# 2          3.0          1
# 3          2.0          0
# 4          3.0          1

# %%
df_test.isna().sum()
# Out:
# Education              0
# Income                 0
# Kidhome                0
# Teenhome               0
# Recency                0
# MntCoke                0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Response               0
# Age                    0
# Spent                  0
# Living_With            0
# Children               0
# Family_Size            0
# Is_Parent              0
# dtype: int64

# %%
# statistical analysis

df_train.describe()
# Out:
#              Income      Kidhome     Teenhome      Recency       MntCoke  \
# count  1.663000e+03  1663.000000  1663.000000  1663.000000  1.663000e+03
# mean   5.201434e+07     0.449188     0.499098    49.061335  3.060469e+05
# std    2.148248e+07     0.544890     0.549449    28.914182  3.392420e+05
# min    1.730000e+06     0.000000     0.000000     0.000000  0.000000e+00
# 25%    3.568800e+07     0.000000     0.000000    24.000000  2.400000e+04
# 50%    5.125000e+07     0.000000     0.000000    50.000000  1.730000e+05
# 75%    6.812200e+07     1.000000     1.000000    74.000000  4.990000e+05
# max    1.623970e+08     2.000000     2.000000    99.000000  1.492000e+06
#
#            MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count    1663.000000     1.663000e+03      1663.000000       1663.000000
# mean    25978.352375     1.664546e+05     37110.042093      26979.555021
# std     39576.041604     2.248949e+05     54348.868950      41273.567857
# min         0.000000     1.000000e+03         0.000000          0.000000
# 25%      1000.000000     1.600000e+04      3000.000000       1000.000000
# 50%      8000.000000     6.800000e+04     12000.000000       8000.000000
# 75%     32000.000000     2.345000e+05     48000.000000      32000.000000
# max    199000.000000     1.725000e+06    259000.000000     198000.000000
#
#         MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count    1663.000000        1663.000000      1663.000000          1663.000000
# mean    43331.328924           2.338545         4.038485             2.682502
# std     50904.197540           1.956260         2.616657             2.980317
# min         0.000000           0.000000         0.000000             0.000000
# 25%      9000.000000           1.000000         2.000000             0.000000
# 50%     24000.000000           2.000000         4.000000             2.000000
# 75%     55000.000000           3.000000         6.000000             4.000000
# max    262000.000000          15.000000        11.000000            28.000000
#
#        NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# count        1663.000000        1663.000000   1663.000000   1663.000000
# mean            5.797956           5.331930      0.072159      0.073963
# std             3.245112           2.451058      0.258828      0.261789
# min             0.000000           0.000000      0.000000      0.000000
# 25%             3.000000           3.000000      0.000000      0.000000
# 50%             5.000000           6.000000      0.000000      0.000000
# 75%             8.000000           7.000000      0.000000      0.000000
# max            13.000000          20.000000      1.000000      1.000000
#
#        AcceptedCmp5  AcceptedCmp1  AcceptedCmp2     Complain     Response  \
# count   1663.000000   1663.000000   1663.000000  1663.000000  1663.000000
# mean       0.069753      0.061936      0.012026     0.010222     0.145520
# std        0.254808      0.241112      0.109037     0.100618     0.352731
# min        0.000000      0.000000      0.000000     0.000000     0.000000
# 25%        0.000000      0.000000      0.000000     0.000000     0.000000
# 50%        0.000000      0.000000      0.000000     0.000000     0.000000
# 75%        0.000000      0.000000      0.000000     0.000000     0.000000
# max        1.000000      1.000000      1.000000     1.000000     1.000000
#
#                Age         Spent     Children  Family_Size    Is_Parent
# count  1663.000000  1.663000e+03  1663.000000  1663.000000  1663.000000
# mean     54.150932  6.059008e+05     0.948286     2.335538     0.710162
# std      12.037325  6.027183e+05     0.759834     0.921977     0.453823
# min      27.000000  5.000000e+03     0.000000     1.000000     0.000000
# 25%      46.000000  6.950000e+04     0.000000     2.000000     0.000000
# 50%      53.000000  3.930000e+05     1.000000     2.000000     1.000000
# 75%      63.000000  1.043500e+06     1.000000     3.000000     1.000000
# max     130.000000  2.525000e+06     3.000000     5.000000     1.000000

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">EXPLORATORY DATA ANALYSIS (EDA)</p>

# %% [markdown]
# ## Univariate Analysis

# %%
# VISUALIZING THE "Education"
df_train['Education'].value_counts().plot(kind='bar',color = 'green')
plt.title("Frequency Of Each Category in the 'Education' Variable ")
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Most of the customers are Graduate.
# 2. Few customers are having the Diploma level education.
# 3. Around 650 peoples are Postgraduates.

# %%
# VISUALIZING THE "Living_With"
df_train['Living_With'].value_counts().plot(kind='bar',color = 'cyan')
plt.title("Frequency Of Each Category in the 'Living_With' Variable ")
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Most of the customers live alone or are single.
# 2. Approximately 650 customers live with their partners and children.

# %%
plt.figure(figsize=(8,8))
sns.distplot(df_train["Income"])
plt.show()

df_train["Income"].plot.box(figsize=(8,8))
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Income follows a normal distribution and exhibits some right-sided skewness (positively skewed).
# 2. The presence of outliers on the higher income side is indicated by the right tail.
# 3. We are neglecting these outliers at this time.

# %%
# VISUALIZING THE "Age"
plt.figure(figsize=(8,8))
sns.distplot(df_train["Age"])
plt.show()

df_train["Age"].plot.box(figsize=(8,8))
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. the feature Age follows a normal distribution and exhibits some right-sided skewness (positively skewed).
# 2. The presence of outliers on the higher Age side is indicated by the right tail.
# 3. We are neglecting these outliers at this time.

# %% [markdown]
# ## Bivariate Analysis

# %%
# How expenses impacts on Education( Education v/s Spent)
sns.barplot(x="Education", y="Spent", data=df_train)
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Customers with postgraduate-level education spend more than other customers.
# 2. Customers with graduate-level education also exhibit the same spending behavior.
# 3. Customers with undergraduate-level education tend to spend less.

# %%
# How 'Living_With' status impacts on spenting( Living_With v/s Spent)
sns.barplot(x="Living_With", y="Spent", data=df_train)
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Customers who live alone, such as singles, are spending more compared to those living with partners and children.
# 2. Both of them are spending a sufficient amount of money.

# %%
# How 'Children' count impacts on spenting( Children v/s Spent)
sns.barplot(x="Children", y="Spent", data=df_train)
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Customers with no children are spending a significant amount.
# 2. There is a negative trend in spending that increases with the number of children

# %% [markdown]
# ## Multivariate Analysis

# %%
#To plot some selected features 

To_Plot = [ "Income", "Recency", "Age", "Spent", "Is_Parent"]
sns.pairplot(df_train[To_Plot], hue= "Is_Parent")
plt.show()

# %%
#correlation amongst the features (Excluding the categorical features)

#correlation matrix
corr=df_train.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, fmt='.2f', annot=True);
plt.show()

# %%
# The data is quite clean and the new features have been included.so move on to data preprocessing

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">DATA PREPROCESSING</p>

# %% [markdown]
# Preprocessing the data to perform clustering operations.
#
# The following steps are applied to preprocess the data:
#
# 1. Label encoding the categorical features
# 2. Scaling the features using the standard scaler
# 3. Creating a subset dataframe for dimensionality reduction

# %%
#Get list of categorical variables
s = (df_train.dtypes == 'object')
object_cols = list(s[s].index)

print("Categorical variables in the dataset:", object_cols)
# Out:
# Categorical variables in the dataset: ['Education', 'Living_With']

# %% [markdown]
# In order to build the machine learning model, all the categorical columns should be converted to numerical

# %% [markdown]
# ## Encoding categorical data

# %%
#Label Encoding the object dtypes.
from sklearn.preprocessing import LabelEncoder
labenc=LabelEncoder()
for i in object_cols:
    df_train[i]=df_train[[i]].apply(labenc.fit_transform)
    
print("All features in training dataset are now numerical")
# Out:
# All features in training dataset are now numerical

# %%
#for testing dataset

#Label Encoding the object dtypes.

for i in object_cols:
    df_test[i]=df_test[[i]].apply(labenc.fit_transform)
    
print("All features in test dataset are now numerical")
# Out:
# All features in test dataset are now numerical

# %%
df_train.head()
# Out:
#    Education      Income  Kidhome  Teenhome  Recency  MntCoke  MntFruits  \
# 0          0  58138000.0        0         0       58   635000      88000
# 1          0  46344000.0        1         1       38    11000       1000
# 2          0  71613000.0        0         0       26   426000      49000
# 3          0  26646000.0        1         0       26    11000       4000
# 4          1  58293000.0        1         0       94   173000      43000
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0           546000           172000             88000         88000
# 1             6000             2000              1000          6000
# 2           127000           111000             21000         42000
# 3            20000            10000              3000          5000
# 4           118000            46000             27000         15000
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  3                8                   10                  4
# 1                  2                1                    1                  2
# 2                  1                8                    2                 10
# 3                  2                2                    0                  4
# 4                  5                5                    3                  6
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  7             0             0             0             0
# 1                  5             0             0             0             0
# 2                  4             0             0             0             0
# 3                  6             0             0             0             0
# 4                  5             0             0             0             0
#
#    AcceptedCmp2  Complain  Response  Age    Spent  Living_With  Children  \
# 0             0         0         1   66  1617000            0         0
# 1             0         0         0   69    27000            0         2
# 2             0         0         0   58   776000            0         0
# 3             0         0         0   39    53000            0         1
# 4             0         0         0   42   422000            1         1
#
#    Family_Size  Is_Parent
# 0            1          0
# 1            3          1
# 2            1          0
# 3            2          1
# 4            3          1

# %% [markdown]
# The features are of different scales, so scale the dataset before building the ML model for better performance

# %% [markdown]
# ## Scaling The Features

# %%
#Creating a copy of data

ds_train = df_train.copy()

# creating a subset of dataframe by deleting the features on deals accepted, compliants and promotions

cols_del = ['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1','AcceptedCmp2', 'Complain', 'Response']
ds_train = ds_train.drop(cols_del, axis=1)

#Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(ds_train)
scaled_ds_train = pd.DataFrame(scaler.transform(ds_train),columns= ds_train.columns )
print("All features are in training dataset are now scaled")
# Out:
# All features are in training dataset are now scaled

# %%
#Creating a copy of data

ds_test = df_test.copy()

# creating a subset of dataframe by deleting the features on deals accepted, compliants and promotions

cols_del = ['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1','AcceptedCmp2', 'Complain', 'Response']
ds_test = ds_test.drop(cols_del, axis=1)

#Scaling
scaler.fit(ds_test)
scaled_ds_test = pd.DataFrame(scaler.transform(ds_test),columns= ds_test.columns )
print("All features are in testing dataset are now scaled")
# Out:
# All features are in testing dataset are now scaled

# %%
#Scaled data to be used for Dimensionality reduction
scaled_ds_train.head()
# Out:
#    Education    Income   Kidhome  Teenhome   Recency   MntCoke  MntFruits  \
# 0   -0.90666  0.285139 -0.824613 -0.908634  0.309238  0.969963   1.567623
# 1   -0.90666 -0.264031  1.011172  0.911918 -0.382672 -0.869986  -0.631338
# 2   -0.90666  0.912583 -0.824613 -0.908634 -0.797819  0.353698   0.581882
# 3   -0.90666 -1.181241  1.011172 -0.908634 -0.797819 -0.869986  -0.555512
# 4    0.55720  0.292357  1.011172 -0.908634  1.554676 -0.392307   0.430229
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0         1.688165         2.482674          1.478884      0.877769
# 1        -0.713680        -0.646207         -0.629637     -0.733585
# 2        -0.175489         1.359958         -0.144920     -0.026161
# 3        -0.651410        -0.498965         -0.581165     -0.753236
# 4        -0.215519         0.163621          0.000496     -0.556729
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0           0.338224         1.514416             2.456014          -0.554217
# 1          -0.173109        -1.161558            -0.564708          -1.170714
# 2          -0.684442         1.514416            -0.229072           1.295274
# 3          -0.173109        -0.779276            -0.900343          -0.554217
# 4           1.360890         0.367570             0.106564           0.062280
#
#    NumWebVisitsMonth       Age     Spent  Living_With  Children  Family_Size  \
# 0           0.680756  0.984657  1.678070    -0.794979 -1.248393    -1.448995
# 1          -0.135464  1.233956 -0.960772    -0.794979  1.384552     0.720909
# 2          -0.543574  0.319857  0.282305    -0.794979 -1.248393    -1.448995
# 3           0.272646 -1.259041 -0.917621    -0.794979  0.068080    -0.364043
# 4          -0.135464 -1.009742 -0.305211     1.257894  0.068080     0.720909
#
#    Is_Parent
# 0  -1.565314
# 1   0.638850
# 2  -1.565314
# 3   0.638850
# 4   0.638850

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">CLUSTERING</p>

# %% [markdown]
# ## Agglomerative clustering
# Agglomerative clustering is a hierarchical clustering method. It involves merging examples until the desired number of clusters is achieved.Before that we need to find out the number of clusters (k) using Elbow method.
#
# ## Steps:
# 1. Findout the no:of clusters(k) using elbow method.
# 2. clustering using the k.

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %%
# using WCSS (Within Clusters Sum of Squares)
# Elbow method

#for this, finding the wcss value for different no: of clusters and then choose the optimum one(elbow)
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_ds_train)
    
    wcss.append(kmeans.inertia_)

# %%
# elbow method-plot
sns.set()
plt.plot(range(1,11),wcss)
plt.title('Elbow-method to find no: of clusters(k)')
plt.xlabel('No: of clusters(k)')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Observations from graph:
# 1. The k value = 4
# 2. After the k=4 , there is no significant drop.
# 3. Also the k with minimum wcss

# %%
# Evaluation- Silhouette Score

from sklearn import metrics
from sklearn.metrics import silhouette_score

score = silhouette_score(scaled_ds_train, kmeans.labels_, metric='euclidean')
score
# Out:
# 0.13522646092237364

# %% [markdown]
# ## Agglomerative Clustering

# %%
#Initiating the Agglomerative Clustering model 
aggclust = AgglomerativeClustering(n_clusters=4)

# fit model and predict clusters
y_pred = aggclust.fit_predict(scaled_ds_train)
scaled_ds_train["Clusters"] = y_pred

#Adding the Clusters feature to the orignal dataframe.
df_train["Clusters"]= y_pred

# %%
df_train['Clusters'].value_counts()
# Out:
# 2    478
# 0    470
# 3    358
# 1    357
# Name: Clusters, dtype: int64

# %%
# for testing dataset

y_test_pred = aggclust.fit_predict(scaled_ds_test)
scaled_ds_test["Clusters"] = y_test_pred
df_test["Clusters"]= y_test_pred

# %%
df_test['Clusters'].value_counts()
# Out:
# 1    223
# 2    151
# 3     84
# 0     81
# Name: Clusters, dtype: int64

# %%
# Plotting the clusters- Training dataset

sns.scatterplot(data = scaled_ds_train,x=scaled_ds_train["Spent"], y=scaled_ds_train["Income"],hue=scaled_ds_train["Clusters"])
plt.title("The Clusters of Training data")
plt.show()

# %%
# Plotting the clusters- Testing dataset

sns.scatterplot(data = scaled_ds_test,x=scaled_ds_test["Spent"], y=scaled_ds_test["Income"],hue=scaled_ds_test["Clusters"])
plt.title("The Clusters of Testing data")
plt.show()

# %%
# silhouette score for agglomerative clustering:

from sklearn import metrics
from sklearn.metrics import silhouette_score

aggclust.fit(scaled_ds_train)
agscore = silhouette_score(scaled_ds_train, aggclust.labels_, metric='euclidean')
agscore
# Out:
# 0.16279914155557867

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">MODEL EVALUATION</p>

# %% [markdown]
# As this involves unsupervised clustering, we lack labeled features for assessing or rating our model's performance. The aim of this section is to examine the structures within the clusters and ascertain their inherent characteristics.
#
# So to accomplish this, we will explore the data within the context of these clusters through exploratory data analysis, ultimately deriving meaningful insights and conclusions.

# %%
# distribution of clusters

pl = sns.countplot(x=df_train["Clusters"])
plt.title("Distribution Of The Clusters-Train dataset")
plt.show()

# %% [markdown]
# ## Observations from the graph:
# 1. Four different clusters are present after performing the clustering algorithm on the given dataset.
# 2. Most of the customers are in grouo-0 and group-2
# 3. the group-1 contains the least number of customers.

# %%
# distribution of clusters-test dataset

pl = sns.countplot(x=df_test["Clusters"])
plt.title("Distribution Of The Clusters-Test dataset")
plt.show()

# %%
# Cluster's Profile Based On Income And Spending-train
sns.scatterplot(data = df_train,x=df_train["Spent"], y=df_train["Income"],hue=df_train["Clusters"])
plt.title("Cluster's Profile Based On Income And Spending-train")
plt.legend()
plt.show()

# %% [markdown]
# Income vs spending plot shows the clusters pattern
#
# 1. Cluster 0: low spending & low income
# 2. Cluster 1: average spending & average income
# 3. Cluster 2: high spending & average income
# 4. Cluster 3: high spending & high income

# %%
# Cluster's Profile Based On Income And Spending-test
sns.scatterplot(data = df_test,x=df_test["Spent"], y=df_test["Income"],hue=df_test["Clusters"])
plt.title("Cluster's Profile Based On Income And Spending-test")
plt.legend()
plt.show()

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">CLUSTER ANALYSIS</p>

# %%
# detailed distribution of clusters as per the various products in the data. 
import warnings
warnings.filterwarnings("ignore")
plt.figure()
sns.swarmplot(x=df_train["Clusters"], y=df_train["Spent"], alpha=0.5)
sns.boxenplot(x=df_train["Clusters"], y=df_train["Spent"])
plt.show()

# %% [markdown]
# ### observations from the plot:
# 1. More spending is by cluster 3 followed by cluser 2.
# 2. Low spending by cluster 1

# %%
# How did our previous campaign perform?

#Creating a feature to get a sum of accepted promotions 
df_train["Total_Promos"] = df_train["AcceptedCmp1"]+ df_train["AcceptedCmp2"]+ df_train["AcceptedCmp3"]+ df_train["AcceptedCmp4"]+ df_train["AcceptedCmp5"]
#Plotting count of total campaign accepted.
plt.figure()
sns.countplot(x=df_train["Total_Promos"],hue=df_train["Clusters"])
plt.title("Count Of Promotion Accepted")
plt.xlabel("Number Of Total Accepted Promotions")
plt.show()

# %% [markdown]
# ### observations from the plot:
# 1. The campaigns have yet to generate a significant response, with a limited number of participants overall.
# 2. No one has engaged in all five campaigns, and there has been a decline in participation across the campaigns.
# 3. So we may need to create better and carefully thought-out marketing campaigns to increase sales.

# %%
#Plotting the number of deals purchased


plt.figure()
sns.boxenplot(x=df_train["Clusters"],y=df_train["NumDealsPurchases"])
plt.title("Number of Deals Purchased")
plt.show()

# %% [markdown]
# ### observations from the plot:
# 1. Unlike advertising campaigns, the special offers worked really well.
# 2. They had the best results with cluster 0 and cluster 2 of customers. But our most important customers in cluster 3(high spent) didn't show much interest in the deals.

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">PROFILING</p>

# %% [markdown]
# Now that the clusters have been formed and their purchasing habits have been analyzed, it's time to identify the individuals within these clusters. This involves profiling the clusters to determine who the star customers are and who may require more attention from the retail store's marketing team.
#
# To make these determinations, relevant customer attributes will be examined within the context of their respective clusters. Conclusions will be drawn based on the findings.

# %%
Personal = [ "Kidhome","Teenhome","Age", "Children", "Family_Size", "Is_Parent", "Education","Living_With"]

for i in Personal:
    plt.figure()
    sns.jointplot(x=df_train[i], y=df_train["Spent"], hue =df_train["Clusters"], kind="kde")
    plt.show()

# %% [markdown]
# ## Observations from the plot: Customer Profiling
# 1. **Cluster-0:**
#
#     * Customers are relatively older peoples, ranges from middle aged to older(35-75).
#
#     * Family contains atleast two peoples and including childrens maximum of 5 peoples.
#
#     * All of them are parents.
#
#     * Atleast one children.
#
#
# 2. **Cluster-1:**
#
#     * Customers are relatively older peoples, ranges from middle aged to older(30-80).
#
#     * Spans all age groups.
#
#     * Family contains atleast one person and including childrens maximum of 3 peoples.
#
#     * Majority are parents.
#
#     * maximum one children.
#
#     * Less spent group of peoples.
#
#
# 3. **Cluster-2:**
#
#     * Customers are relatively younger peoples, ranges from 20 to maximim 50 age.
#
#     * Family contains atleat 2 and maximim 3 members.
#
#     * Majority are parents.
#
#     * Contains minimum 1 children and maximum 2 childrens.
#
#     * Good spending culture.
#
#
# 4. **Cluster-3:**
#
#     * Customers are relatively older peoples, ranges from 35 to maximim 80 age.
#
#     * Most of them are living alone or single.
#
#     * Family contains maxmimum 2 members.
#
#     * Majority of them are not parents.
#
#     * Good spending culture.

# %% [markdown]
# # Classification Algorithm

# %%
df_train.head()
# Out:
#    Education      Income  Kidhome  Teenhome  Recency  MntCoke  MntFruits  \
# 0          0  58138000.0        0         0       58   635000      88000
# 1          0  46344000.0        1         1       38    11000       1000
# 2          0  71613000.0        0         0       26   426000      49000
# 3          0  26646000.0        1         0       26    11000       4000
# 4          1  58293000.0        1         0       94   173000      43000
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0           546000           172000             88000         88000
# 1             6000             2000              1000          6000
# 2           127000           111000             21000         42000
# 3            20000            10000              3000          5000
# 4           118000            46000             27000         15000
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  3                8                   10                  4
# 1                  2                1                    1                  2
# 2                  1                8                    2                 10
# 3                  2                2                    0                  4
# 4                  5                5                    3                  6
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  7             0             0             0             0
# 1                  5             0             0             0             0
# 2                  4             0             0             0             0
# 3                  6             0             0             0             0
# 4                  5             0             0             0             0
#
#    AcceptedCmp2  Complain  Response  Age    Spent  Living_With  Children  \
# 0             0         0         1   66  1617000            0         0
# 1             0         0         0   69    27000            0         2
# 2             0         0         0   58   776000            0         0
# 3             0         0         0   39    53000            0         1
# 4             0         0         0   42   422000            1         1
#
#    Family_Size  Is_Parent  Clusters  Total_Promos
# 0            1          0         3             0
# 1            3          1         1             0
# 2            1          0         3             0
# 3            2          1         0             0
# 4            3          1         0             0

# %%
df_test.head()
# Out:
#    Education      Income  Kidhome  Teenhome  Recency  MntCoke  MntFruits  \
# 0          0  38232000.0        1         1       84    43000       5000
# 1          1  22554000.0        1         1       38    27000          0
# 2          1  23536000.0        1         0       53     6000          0
# 3          0  49413000.0        0         1       88   205000       7000
# 4          0  42231000.0        1         1       99    24000          0
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0            28000             7000              6000         33000
# 1            10000                0                 0          4000
# 2             3000                0                 0          1000
# 3            41000             3000              2000         46000
# 4             8000                0              1000          4000
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  4                3                    1                  3
# 1                  4                2                    0                  4
# 2                  1                0                    0                  3
# 3                  2                4                    2                  5
# 4                  1                1                    0                  3
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  5             0             0             0             0
# 1                  5             0             0             0             0
# 2                  3             0             0             0             0
# 3                  5             0             0             0             0
# 4                  5             0             0             0             0
#
#    AcceptedCmp2  Complain  Response  Age   Spent  Living_With  Children  \
# 0             0         0         0   52  122000            0       1.0
# 1             0         0         0   68   41000            1       2.0
# 2             0         0         0   40   10000            1       1.0
# 3             0         0         0   71  304000            1       0.0
# 4             0         0         0   54   37000            1       1.0
#
#    Family_Size  Is_Parent  Clusters
# 0          2.0          1         1
# 1          4.0          1         1
# 2          3.0          1         1
# 3          2.0          0         3
# 4          3.0          1         1

# %%
# scale the dataset before modelling
df_train=df_train.drop("Total_Promos",axis=1)


from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_train)
df_scaled_train = pd.DataFrame(scaler.transform(df_train),columns= df_train.columns )
print("All features  in training dataset are now scaled")
# Out:
# All features  in training dataset are now scaled

# %%
# testing dataset scaling

scaler.fit(df_test)
df_scaled_test = pd.DataFrame(scaler.transform(df_test),columns= df_test.columns )
print("All features  in testing dataset are now scaled")
# Out:
# All features  in testing dataset are now scaled

# %%
df_scaled_train.head()
# Out:
#    Education    Income   Kidhome  Teenhome   Recency   MntCoke  MntFruits  \
# 0   -0.90666  0.285139 -0.824613 -0.908634  0.309238  0.969963   1.567623
# 1   -0.90666 -0.264031  1.011172  0.911918 -0.382672 -0.869986  -0.631338
# 2   -0.90666  0.912583 -0.824613 -0.908634 -0.797819  0.353698   0.581882
# 3   -0.90666 -1.181241  1.011172 -0.908634 -0.797819 -0.869986  -0.555512
# 4    0.55720  0.292357  1.011172 -0.908634  1.554676 -0.392307   0.430229
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0         1.688165         2.482674          1.478884      0.877769
# 1        -0.713680        -0.646207         -0.629637     -0.733585
# 2        -0.175489         1.359958         -0.144920     -0.026161
# 3        -0.651410        -0.498965         -0.581165     -0.753236
# 4        -0.215519         0.163621          0.000496     -0.556729
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0           0.338224         1.514416             2.456014          -0.554217
# 1          -0.173109        -1.161558            -0.564708          -1.170714
# 2          -0.684442         1.514416            -0.229072           1.295274
# 3          -0.173109        -0.779276            -0.900343          -0.554217
# 4           1.360890         0.367570             0.106564           0.062280
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0           0.680756     -0.278874     -0.282613     -0.273832     -0.256955
# 1          -0.135464     -0.278874     -0.282613     -0.273832     -0.256955
# 2          -0.543574     -0.278874     -0.282613     -0.273832     -0.256955
# 3           0.272646     -0.278874     -0.282613     -0.273832     -0.256955
# 4          -0.135464     -0.278874     -0.282613     -0.273832     -0.256955
#
#    AcceptedCmp2  Complain  Response       Age     Spent  Living_With  \
# 0     -0.110331 -0.101627  2.423201  0.984657  1.678070    -0.794979
# 1     -0.110331 -0.101627 -0.412677  1.233956 -0.960772    -0.794979
# 2     -0.110331 -0.101627 -0.412677  0.319857  0.282305    -0.794979
# 3     -0.110331 -0.101627 -0.412677 -1.259041 -0.917621    -0.794979
# 4     -0.110331 -0.101627 -0.412677 -1.009742 -0.305211     1.257894
#
#    Children  Family_Size  Is_Parent  Clusters
# 0 -1.248393    -1.448995  -1.565314  1.404178
# 1  1.384552     0.720909   0.638850 -0.390709
# 2 -1.248393    -1.448995  -1.565314  1.404178
# 3  0.068080    -0.364043   0.638850 -1.288152
# 4  0.068080     0.720909   0.638850 -1.288152

# %%
df_scaled_test.head()
# Out:
#    Education    Income   Kidhome  Teenhome   Recency   MntCoke  MntFruits  \
# 0  -0.856164 -0.424901  1.130153  0.885722  1.211199 -0.774480  -0.551444
# 1   0.604192 -0.883403  1.130153  0.885722 -0.370767 -0.822785  -0.674713
# 2   0.604192 -0.854684  1.130153 -1.008739  0.145091 -0.886184  -0.674713
# 3  -0.856164 -0.097913 -0.822259  0.885722  1.348762 -0.285397  -0.502136
# 4  -0.856164 -0.307950  1.130153  0.885722  1.727058 -0.831842  -0.674713
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0        -0.621140        -0.565878         -0.513428     -0.232669
# 1        -0.702138        -0.692821         -0.664747     -0.766010
# 2        -0.733638        -0.692821         -0.664747     -0.821183
# 3        -0.562641        -0.638416         -0.614308      0.006415
# 4        -0.711138        -0.692821         -0.639527     -0.766010
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0           0.928681        -0.396456            -0.586144          -0.852703
# 1           0.928681        -0.719251            -0.949701          -0.546706
# 2          -0.708917        -1.364840            -0.949701          -0.852703
# 3          -0.163051        -0.073662            -0.222586          -0.240710
# 4          -0.708917        -1.042045            -0.949701          -0.852703
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0          -0.127401     -0.290701     -0.283126     -0.301816     -0.275406
# 1          -0.127401     -0.290701     -0.283126     -0.301816     -0.275406
# 2          -0.980433     -0.290701     -0.283126     -0.301816     -0.275406
# 3          -0.127401     -0.290701     -0.283126     -0.301816     -0.275406
# 4          -0.127401     -0.290701     -0.283126     -0.301816     -0.275406
#
#    AcceptedCmp2  Complain  Response       Age     Spent  Living_With  \
# 0      -0.13749 -0.086468 -0.447711 -0.192904 -0.800730    -0.795822
# 1      -0.13749 -0.086468 -0.447711  1.165142 -0.935531     1.256562
# 2      -0.13749 -0.086468 -0.447711 -1.211439 -0.987122     1.256562
# 3      -0.13749 -0.086468 -0.447711  1.419775 -0.497843     1.256562
# 4      -0.13749 -0.086468 -0.447711 -0.023149 -0.942188     1.256562
#
#    Children  Family_Size  Is_Parent  Clusters
# 0  0.158127    -0.331697   0.658415 -0.476469
# 1  1.555344     2.084311   0.658415 -0.476469
# 2  0.158127     0.876307   0.658415 -0.476469
# 3 -1.239091    -0.331697  -1.518798  1.681656
# 4  0.158127     0.876307   0.658415 -0.476469

# %%
#For training dataset


x_train=df_scaled_train.drop(['Response'], axis=1)
y_train=df_train['Response']

#for testing dataset
x_test=df_scaled_test.drop(['Response'], axis=1)
y_test=df_test['Response']

# %%
# applying random forest classifier algorithm for classification

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
ranfo=RandomForestClassifier(criterion='gini',max_depth=3,random_state=50)
ranfo.fit(x_train,y_train)
pred=ranfo.predict(x_test)

# %%
# accuracy score
score=accuracy_score(y_test,pred)
score
# Out:
# 0.8385899814471243

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">CONCLUSION</p>

# %% [markdown]
# In conclusion, through the process of unsupervised clustering,  agglomerative clustering techniques, I was able to create four distinct customer clusters. These clusters served as a foundation for profiling customers based on their family structures and income/spending behaviors. The insights derived from this analysis can greatly enhance our ability to formulate more targeted and effective marketing strategies for our diverse customer segments, ultimately driving the success of our business

# %% [markdown]
# # <p style="background-color:#182F2F;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:10px 10px;">END</p>

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;">Thank You</p>
